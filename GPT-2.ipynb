# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Load pre-trained GPT model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Input text for generation
input_text = "Machine learning is a field of"
input_ids = tokenizer.encode(input_text, return_tensors='pt')

# Generate continuation with attention mask and control parameters
attention_mask = torch.ones(input_ids.shape, device=input_ids.device)
output = model.generate(input_ids,
                        attention_mask=attention_mask,
                        max_length=100,
                        num_return_sequences=1,
                        pad_token_id=tokenizer.eos_token_id,  # Prevent padding issues
                        no_repeat_ngram_size=2,               # Prevent repetition
                        top_k=100,                             # Top-k sampling
                        top_p=0.95,                           # Nucleus sampling
                        temperature=0.7                        # Control randomness
                       )

generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Machine learning is a field of study that has been around for a long time. It is not a new field, but it has become a very important one.
#
# The first step in the development of machine learning was to develop a model of the human brain. This model was developed by Dr. John D. Dolan, a neuroscientist at the University of California, Berkeley. He developed a neural network that was able to learn from the brain of a human. The model is called the

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Load pre-trained GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Input text for summarization
text = """
Machine learning is a field of artificial intelligence that focuses on creating systems that learn from data.
These systems improve their performance over time without being explicitly programmed. Machine learning has become
a critical tool in fields such as healthcare, finance, and autonomous vehicles.
"""

# Create a prompt for summarization
prompt = f"Summarize the following:\n{text}\nSummary:"

# Tokenize and generate summary
input_ids = tokenizer.encode(prompt, return_tensors='pt')
summary_ids = model.generate(input_ids, max_length=140, num_return_sequences=1, no_repeat_ngram_size=1, top_k=50, top_p=0.95)

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print("Summary:", summary)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Summary: Summarize the following:
#
# Machine learning is a field of artificial intelligence that focuses on creating systems that learn from data.
# These systems improve their performance over time without being explicitly programmed. Machine learning has become
# a critical tool in fields such as healthcare, finance, and autonomous vehicles.
#
# Summary: The goal here was to create an algorithm for machine-learning algorithms which would be able (and likely will) perform well at high levels using only human input or with no external inputs whatsoever - but not necessarily by any means necessary! This approach could also help us understand how we can use AI technology more effectively than ever before...

# %%
from transformers import MarianMTModel, MarianTokenizer

# Load pre-trained MarianMT model and tokenizer for English to French translation
translation_model_name = 'Helsinki-NLP/opus-mt-en-fr'
translator_tokenizer = MarianTokenizer.from_pretrained(translation_model_name)
translator_model = MarianMTModel.from_pretrained(translation_model_name)

# Input text for translation
text_to_translate = "Machine learning is a field of artificial intelligence."

# Tokenize and translate
translated_inputs = translator_tokenizer(text_to_translate, return_tensors='pt', padding=True, truncation=True)
translated_ids = translator_model.generate(translated_inputs['input_ids'])

translated_text = translator_tokenizer.decode(translated_ids[0], skip_special_tokens=True)
print("Translated text:", translated_text)
# Out:
# Downloading:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/784k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/287M [00:00<?, ?B/s]
# Translated text: L'apprentissage automatique est un domaine d'intelligence artificielle.

# %%
# Input context and question
context = """
Machine learning is a field of artificial intelligence that focuses on creating systems that learn from data.
These systems improve their performance over time without being explicitly programmed.
"""
question = "What is machine learning?"

# Create a prompt for question answering
qa_prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"

# Tokenize and generate answer
qa_input_ids = tokenizer.encode(qa_prompt, return_tensors='pt')
qa_output_ids = model.generate(qa_input_ids, max_length=100, num_return_sequences=1, no_repeat_ngram_size=2, top_k=50, top_p=0.95)

answer = tokenizer.decode(qa_output_ids[0], skip_special_tokens=True)
print("Answer:", answer)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Answer: Context:
# Machine learning is a field of artificial intelligence that focuses on creating systems that learn from data.
# These systems improve their performance over time without being explicitly programmed.
#
# Question: What is machine learning?
# Answer: Machine learning involves learning from a set of data sets. The data set is then used to create a model of the system. This model is used in the design of algorithms and other systems. Machine Learning is also used for the development of new algorithms. In this way
